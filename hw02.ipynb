# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
train_df = pd.read_csv('./data/train.csv')#.astype({'Sex': 'category'})
test_df = pd.read_csv('./data/test.csv')
combine = [train_df, test_df]

# %%
train_df.shape
# Out:
# (891, 12)

# %% [markdown]
# Column names

# %% [markdown]
# Question 1

# %%
for c in train_df.columns:
    print(c)
# Out:
# PassengerId
# Survived
# Pclass
# Name
# Sex
# Age
# SibSp
# Parch
# Ticket
# Fare
# Cabin
# Embarked

# %% [markdown]
# Questions 2,3,4,5 and 6
# (Coupled with manual data inspection)

# %% [markdown]
# Training Data Info

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# Test Data Info

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %% [markdown]
# Question 7

# %%
train_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# Question 8

# %%
train_df[['Survived','Pclass','Sex','Embarked']].astype('object').describe()
# Out:
#         Survived  Pclass   Sex Embarked
# count        891     891   891      889
# unique         2       3     2        3
# top            0       3  male        S
# freq         549     491   577      644

# %% [markdown]
# Question 9

# %%
train_df.groupby(['Pclass'])['Survived'].agg(['mean', 'count'])
# Out:
#         Survived
#             mean count
# Pclass
# 1       0.629630   216
# 2       0.472826   184
# 3       0.242363   491

# %% [markdown]
# Question 10

# %%
train_df.groupby(['Sex'])['Survived'].agg(['mean', 'count'])
# Out:
#             mean  count
# Sex
# female  0.742038    314
# male    0.188908    577

# %% [markdown]
# Question 11

# %%
train_df.groupby('Survived')['Age'].plot.hist(alpha=0.4)
# Out:
# Survived
# 0    AxesSubplot(0.125,0.125;0.775x0.755)
# 1    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: Age, dtype: object

# %%
train_df[['Survived','Age']].groupby('Survived').hist(column='Age',bins=20)
# Out:
# Survived
# 0    [[AxesSubplot(0.125,0.125;0.775x0.755)]]
# 1    [[AxesSubplot(0.125,0.125;0.775x0.755)]]
# dtype: object

# %% [markdown]
# Question 12

# %%
train_df[['Survived','Age','Pclass']].groupby(['Survived','Pclass']).hist(column='Age',bins=20)
# Out:
# Survived  Pclass
# 0         1         [[AxesSubplot(0.125,0.125;0.775x0.755)]]
#           2         [[AxesSubplot(0.125,0.125;0.775x0.755)]]
#           3         [[AxesSubplot(0.125,0.125;0.775x0.755)]]
# 1         1         [[AxesSubplot(0.125,0.125;0.775x0.755)]]
#           2         [[AxesSubplot(0.125,0.125;0.775x0.755)]]
#           3         [[AxesSubplot(0.125,0.125;0.775x0.755)]]
# dtype: object
